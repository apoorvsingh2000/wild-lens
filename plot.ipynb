# %%
import torch.nn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vit_full_losses = torch.load('../Best_Models/vit_full/model-losses.pth')

# %%
vit_full_losses
# Out:
# {'train_losses': tensor([2.1052, 1.9421, 2.4840, 2.6511, 2.4988, 2.4550, 2.2564, 2.1531, 2.0714,
#          2.0013, 1.9177, 1.8563, 1.7908, 1.7058, 1.6776, 1.6430, 1.6270, 1.5702,
#          1.5500, 1.5380, 1.5126, 1.4815, 1.4656, 1.4510, 1.4410, 1.4217]),
#  'validation_losses': tensor([1.8631, 2.2017, 2.7359, 2.7313, 2.8788, 2.2509, 2.2167, 2.0759, 2.0746,
#          2.1097, 1.9371, 1.8958, 1.7743, 1.7169, 1.7016, 1.6922, 1.6287, 1.5980,
#          1.5825, 1.5740, 1.5568, 1.5262, 1.5329, 1.4943, 1.4962, 1.4755]),
#  'start': 0,
#  'num_epochs': 26}

# %%
sns.set(style='darkgrid')

# %%
plt.figure(figsize=(10, 6))

plt.plot(range(vit_full_losses['num_epochs']), vit_full_losses['validation_losses'], label='Validation loss', color='red')
plt.plot(range(vit_full_losses['num_epochs']), vit_full_losses['train_losses'], label='Train loss', color='blue')
plt.title('Vision Transformers Full Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('ViT-Full-loss_curves.png')

plt.show()

# %%
vit_frozen_losses = torch.load('../Best_Models/vit_frozen/model-losses.pth')

# %%
vit_frozen_losses
# Out:
# {'train_losses': tensor([2.1293, 2.3190, 2.6236, 2.5360, 2.4047, 2.2563, 2.1903, 2.2113, 2.1711,
#          2.0838, 2.0863, 2.0213, 2.0161, 1.9480, 1.9201, 1.8834]),
#  'validation_losses': tensor([2.0072, 2.8329, 2.4662, 2.5163, 2.3169, 2.2656, 2.1300, 2.1467, 2.1528,
#          2.0382, 2.0874, 1.9725, 2.0242, 1.9632, 1.8978, 1.8588]),
#  'start': 0,
#  'num_epochs': 16}

# %%
plt.figure(figsize=(10, 6))

plt.plot(range(vit_frozen_losses['num_epochs']), vit_frozen_losses['validation_losses'], label='Validation loss', color='red')
plt.plot(range(vit_frozen_losses['num_epochs']), vit_frozen_losses['train_losses'], label='Train loss', color='blue')
plt.title('Vision Transformers Frozen Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('ViT-Frozen-loss_curves.png')
plt.ylim(1.8, 2.9)

plt.show()
